# %% [markdown]
# # 3.2 Models

# %% [markdown]
# En esta iteración nos desharemos de los duplicados que surgen tras la eliminación del identificador único `EmployeeID`

# %%
import pandas as pd

import sys
sys.path.append("..")
from src.support_models import *

import warnings
warnings.filterwarnings("ignore")

# %%
# %load_ext autoreload
# %autoreload 2

# %%
parametros_logistic =  [{'penalty': ['l1'], 'solver': ['saga'], 'C': [0.001, 0.01, 0.1, 1, 10, 100], 'max_iter': [10000]},
    {'penalty': ['l2'], 'solver': ['liblinear'], 'C': [0.001, 0.01, 0.1, 1, 10, 100], 'max_iter': [10000]},
    {'penalty': ['elasticnet'], 'solver': ['saga'], 'l1_ratio': [0.1, 0.3, 0.5, 0.7, 0.9], 'C': [0.001, 0.01, 0.1, 1, 10, 100], 'max_iter': [10000]},
    {'penalty': ['none'], 'solver': ['lbfgs'], 'max_iter': [10000]}]

parametros_dt = {'max_depth': [4, 10, 14, 25, 40],
            'min_samples_split': [6, 8, 10, 15, 20, 25],
            'min_samples_leaf': [6, 8, 10, 15, 20, 25],
            'max_leaf_nodes': [10, 15, 20, 25, 40, 60, 90, 110]}

parametros_rf = {
            'n_estimators' : [10,20,30,40],
            'max_depth': [5, 10, 15],
            'min_samples_split': [8, 10, 15, 20],
            'min_samples_leaf': [6, 8, 10, 15, 20],
            'max_leaf_nodes': [10, 15, 20, 25]
}

parametros_gb = {
    'n_estimators': [50,100],
    'max_depth': [3,5,7],
    'min_samples_split': [3,4,7],
    'min_samples_leaf': [3,4,7],
    'max_leaf_nodes': [6,10,12]
}

parametros_xgb = {
        'n_estimators': [100, 200],
        'learning_rate': [0.01, 0.1, 0.2],
        'max_depth': [3, 4, 5],
        'min_child_weight': [1, 3, 5],
        'subsample': [0.8, 1.0],
        'colsample_bytree': [0.8, 1.0]
}

parametros_svc = {
    'C': [0.1, 1, 10, 100],
    'kernel': ['linear', 'rbf', 'poly'],
    'gamma': ['scale', 'auto'],
    'degree': [2, 3]}

# %%
df = pd.read_pickle("../datos/prepped.pkl")

# %%
df_nodup = df.drop_duplicates()

# %%
df_nodup.to_pickle("../datos/prepped_nodup.pkl")

# %%
X = df_nodup.drop(columns=["Attrition"])
y = df_nodup["Attrition"]

# %%
model_nodup = ClassificationModel(X, y)

# %%
model_nodup.train(model_type="logistic", scoring="recall", params=parametros_logistic, verbose=1)
model_nodup.train(model_type="decision_tree", scoring="recall", params=parametros_dt, verbose=1)
model_nodup.train(model_type="gradient_boosting", scoring="recall", params=parametros_gb, verbose=1)
model_nodup.train(model_type="xgboost", scoring="recall", params=parametros_xgb, verbose=1)
model_nodup.train(model_type="random_forest", scoring="recall", params=parametros_rf, verbose=1)
model_nodup.train(model_type="svc", scoring="recall", params=parametros_svc, verbose=1)
# Out:
# Fitting 5 folds for each of 43 candidates, totalling 215 fits
# Fitting 5 folds for each of 1440 candidates, totalling 7200 fits
# Fitting 5 folds for each of 162 candidates, totalling 810 fits
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# Fitting 5 folds for each of 960 candidates, totalling 4800 fits
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# SVC(C=10, kernel='poly', random_state=42)

# %%
model_nodup.plot_roc_curves()
# Out:
# El modelo 'svc' no soporta la función predict_proba y no se puede graficar la curva ROC.
# El modelo 'svc' no soporta la función predict_proba y no se puede graficar la curva ROC.

# %%
model_nodup.plot_confusion_matrix()

# %%
df_metrics_nodup = pd.DataFrame()
for k in model_nodup.resultados.keys():
    df_it = model_nodup.resultados[k]["metrics"]
    df_it["method"] = k
    df_metrics_nodup = pd.concat([df_metrics_nodup, df_it])

df_resultados_colores_nodup = df_metrics_nodup.copy()
df_resultados_colores_nodup.reset_index(inplace = True)
df_resultados_colores_nodup = df_resultados_colores_nodup.style.apply(color_filas_por_modelo, axis=1)
df_resultados_colores_nodup
# Out:
# <style type="text/css">
# #T_5b7e8_row0_col0, #T_5b7e8_row0_col1, #T_5b7e8_row0_col2, #T_5b7e8_row0_col3, #T_5b7e8_row0_col4, #T_5b7e8_row0_col5, #T_5b7e8_row0_col6, #T_5b7e8_row0_col7, #T_5b7e8_row0_col8, #T_5b7e8_row0_col9, #T_5b7e8_row1_col0, #T_5b7e8_row1_col1, #T_5b7e8_row1_col2, #T_5b7e8_row1_col3, #T_5b7e8_row1_col4, #T_5b7e8_row1_col5, #T_5b7e8_row1_col6, #T_5b7e8_row1_col7, #T_5b7e8_row1_col8, #T_5b7e8_row1_col9 {
#   background-color: #b3d1ff;
#   color: black;
# }
# #T_5b7e8_row2_col0, #T_5b7e8_row2_col1, #T_5b7e8_row2_col2, #T_5b7e8_row2_col3, #T_5b7e8_row2_col4, #T_5b7e8_row2_col5, #T_5b7e8_row2_col6, #T_5b7e8_row2_col7, #T_5b7e8_row2_col8, #T_5b7e8_row2_col9, #T_5b7e8_row3_col0, #T_5b7e8_row3_col1, #T_5b7e8_row3_col2, #T_5b7e8_row3_col3, #T_5b7e8_row3_col4, #T_5b7e8_row3_col5, #T_5b7e8_row3_col6, #T_5b7e8_row3_col7, #T_5b7e8_row3_col8, #T_5b7e8_row3_col9 {
#   background-color: #e6b3e0;
#   color: black;
# }
# #T_5b7e8_row4_col0, #T_5b7e8_row4_col1, #T_5b7e8_row4_col2, #T_5b7e8_row4_col3, #T_5b7e8_row4_col4, #T_5b7e8_row4_col5, #T_5b7e8_row4_col6, #T_5b7e8_row4_col7, #T_5b7e8_row4_col8, #T_5b7e8_row4_col9, #T_5b7e8_row5_col0, #T_5b7e8_row5_col1, #T_5b7e8_row5_col2, #T_5b7e8_row5_col3, #T_5b7e8_row5_col4, #T_5b7e8_row5_col5, #T_5b7e8_row5_col6, #T_5b7e8_row5_col7, #T_5b7e8_row5_col8, #T_5b7e8_row5_col9 {
#   background-color: #ffd9b3;
#   color: black;
# }
# #T_5b7e8_row6_col0, #T_5b7e8_row6_col1, #T_5b7e8_row6_col2, #T_5b7e8_row6_col3, #T_5b7e8_row6_col4, #T_5b7e8_row6_col5, #T_5b7e8_row6_col6, #T_5b7e8_row6_col7, #T_5b7e8_row6_col8, #T_5b7e8_row6_col9, #T_5b7e8_row7_col0, #T_5b7e8_row7_col1, #T_5b7e8_row7_col2, #T_5b7e8_row7_col3, #T_5b7e8_row7_col4, #T_5b7e8_row7_col5, #T_5b7e8_row7_col6, #T_5b7e8_row7_col7, #T_5b7e8_row7_col8, #T_5b7e8_row7_col9 {
#   background-color: #f7b3c2;
#   color: black;
# }
# #T_5b7e8_row8_col0, #T_5b7e8_row8_col1, #T_5b7e8_row8_col2, #T_5b7e8_row8_col3, #T_5b7e8_row8_col4, #T_5b7e8_row8_col5, #T_5b7e8_row8_col6, #T_5b7e8_row8_col7, #T_5b7e8_row8_col8, #T_5b7e8_row8_col9, #T_5b7e8_row9_col0, #T_5b7e8_row9_col1, #T_5b7e8_row9_col2, #T_5b7e8_row9_col3, #T_5b7e8_row9_col4, #T_5b7e8_row9_col5, #T_5b7e8_row9_col6, #T_5b7e8_row9_col7, #T_5b7e8_row9_col8, #T_5b7e8_row9_col9 {
#   background-color: #c2f0c2;
#   color: black;
# }
# #T_5b7e8_row10_col0, #T_5b7e8_row10_col1, #T_5b7e8_row10_col2, #T_5b7e8_row10_col3, #T_5b7e8_row10_col4, #T_5b7e8_row10_col5, #T_5b7e8_row10_col6, #T_5b7e8_row10_col7, #T_5b7e8_row10_col8, #T_5b7e8_row10_col9, #T_5b7e8_row11_col0, #T_5b7e8_row11_col1, #T_5b7e8_row11_col2, #T_5b7e8_row11_col3, #T_5b7e8_row11_col4, #T_5b7e8_row11_col5, #T_5b7e8_row11_col6, #T_5b7e8_row11_col7, #T_5b7e8_row11_col8, #T_5b7e8_row11_col9 {
#   background-color: #dbdcff;
#   color: black;
# }
# </style>
# <table id="T_5b7e8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b7e8_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_5b7e8_level0_col1" class="col_heading level0 col1" >precision</th>
#       <th id="T_5b7e8_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_5b7e8_level0_col3" class="col_heading level0 col3" >recall</th>
#       <th id="T_5b7e8_level0_col4" class="col_heading level0 col4" >f1_score</th>
#       <th id="T_5b7e8_level0_col5" class="col_heading level0 col5" >kappa</th>
#       <th id="T_5b7e8_level0_col6" class="col_heading level0 col6" >auc</th>
#       <th id="T_5b7e8_level0_col7" class="col_heading level0 col7" >time</th>
#       <th id="T_5b7e8_level0_col8" class="col_heading level0 col8" >n_jobs</th>
#       <th id="T_5b7e8_level0_col9" class="col_heading level0 col9" >method</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b7e8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5b7e8_row0_col0" class="data row0 col0" >train</td>
#       <td id="T_5b7e8_row0_col1" class="data row0 col1" >0.684783</td>
#       <td id="T_5b7e8_row0_col2" class="data row0 col2" >0.858752</td>
#       <td id="T_5b7e8_row0_col3" class="data row0 col3" >0.319797</td>
#       <td id="T_5b7e8_row0_col4" class="data row0 col4" >0.435986</td>
#       <td id="T_5b7e8_row0_col5" class="data row0 col5" >0.367210</td>
#       <td id="T_5b7e8_row0_col6" class="data row0 col6" >0.824499</td>
#       <td id="T_5b7e8_row0_col7" class="data row0 col7" >0.003005</td>
#       <td id="T_5b7e8_row0_col8" class="data row0 col8" >None</td>
#       <td id="T_5b7e8_row0_col9" class="data row0 col9" >logistic</td>
#     </tr>
#     <tr>
#       <th id="T_5b7e8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5b7e8_row1_col0" class="data row1 col0" >test</td>
#       <td id="T_5b7e8_row1_col1" class="data row1 col1" >0.410256</td>
#       <td id="T_5b7e8_row1_col2" class="data row1 col2" >0.832323</td>
#       <td id="T_5b7e8_row1_col3" class="data row1 col3" >0.210526</td>
#       <td id="T_5b7e8_row1_col4" class="data row1 col4" >0.278261</td>
#       <td id="T_5b7e8_row1_col5" class="data row1 col5" >0.194364</td>
#       <td id="T_5b7e8_row1_col6" class="data row1 col6" >0.736277</td>
#       <td id="T_5b7e8_row1_col7" class="data row1 col7" >0.003005</td>
#       <td id="T_5b7e8_row1_col8" class="data row1 col8" >None</td>
#       <td id="T_5b7e8_row1_col9" class="data row1 col9" >logistic</td>
#     </tr>
#     <tr>
#       <th id="T_5b7e8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5b7e8_row2_col0" class="data row2 col0" >train</td>
#       <td id="T_5b7e8_row2_col1" class="data row2 col1" >0.772152</td>
#       <td id="T_5b7e8_row2_col2" class="data row2 col2" >0.903813</td>
#       <td id="T_5b7e8_row2_col3" class="data row2 col3" >0.619289</td>
#       <td id="T_5b7e8_row2_col4" class="data row2 col4" >0.687324</td>
#       <td id="T_5b7e8_row2_col5" class="data row2 col5" >0.631297</td>
#       <td id="T_5b7e8_row2_col6" class="data row2 col6" >0.874717</td>
#       <td id="T_5b7e8_row2_col7" class="data row2 col7" >0.001996</td>
#       <td id="T_5b7e8_row2_col8" class="data row2 col8" >12</td>
#       <td id="T_5b7e8_row2_col9" class="data row2 col9" >decision_tree</td>
#     </tr>
#     <tr>
#       <th id="T_5b7e8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5b7e8_row3_col0" class="data row3 col0" >test</td>
#       <td id="T_5b7e8_row3_col1" class="data row3 col1" >0.402985</td>
#       <td id="T_5b7e8_row3_col2" class="data row3 col2" >0.820202</td>
#       <td id="T_5b7e8_row3_col3" class="data row3 col3" >0.355263</td>
#       <td id="T_5b7e8_row3_col4" class="data row3 col4" >0.377622</td>
#       <td id="T_5b7e8_row3_col5" class="data row3 col5" >0.273032</td>
#       <td id="T_5b7e8_row3_col6" class="data row3 col6" >0.652525</td>
#       <td id="T_5b7e8_row3_col7" class="data row3 col7" >0.001996</td>
#       <td id="T_5b7e8_row3_col8" class="data row3 col8" >12</td>
#       <td id="T_5b7e8_row3_col9" class="data row3 col9" >decision_tree</td>
#     </tr>
#     <tr>
#       <th id="T_5b7e8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5b7e8_row4_col0" class="data row4 col0" >train</td>
#       <td id="T_5b7e8_row4_col1" class="data row4 col1" >1.000000</td>
#       <td id="T_5b7e8_row4_col2" class="data row4 col2" >0.980936</td>
#       <td id="T_5b7e8_row4_col3" class="data row4 col3" >0.888325</td>
#       <td id="T_5b7e8_row4_col4" class="data row4 col4" >0.940860</td>
#       <td id="T_5b7e8_row4_col5" class="data row4 col5" >0.929544</td>
#       <td id="T_5b7e8_row4_col6" class="data row4 col6" >0.999422</td>
#       <td id="T_5b7e8_row4_col7" class="data row4 col7" >0.005998</td>
#       <td id="T_5b7e8_row4_col8" class="data row4 col8" >12</td>
#       <td id="T_5b7e8_row4_col9" class="data row4 col9" >gradient_boosting</td>
#     </tr>
#     <tr>
#       <th id="T_5b7e8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5b7e8_row5_col0" class="data row5 col0" >test</td>
#       <td id="T_5b7e8_row5_col1" class="data row5 col1" >0.590909</td>
#       <td id="T_5b7e8_row5_col2" class="data row5 col2" >0.862626</td>
#       <td id="T_5b7e8_row5_col3" class="data row5 col3"

# %%
from sklearn.preprocessing import LabelEncoder
from imblearn.combine import SMOTETomek


categorical_columns = df_nodup.drop(columns="Attrition").select_dtypes(include=["object", "category"]).columns
df_encoded = df_nodup.copy()

label_encoders = {}
for col in categorical_columns:
    le = LabelEncoder()
    df_encoded[col] = le.fit_transform(df_encoded[col])
    label_encoders[col] = le

X = df_encoded.drop(columns="Attrition")
y = df_encoded["Attrition"]


smote_tomek = SMOTETomek(random_state=42)
X_resampled, y_resampled = smote_tomek.fit_resample(X, y)

for col in categorical_columns:
    X_resampled[col] = label_encoders[col].inverse_transform(X_resampled[col])

# %%
model_resampled = ClassificationModel(X_resampled, y_resampled)

# %%
model_resampled.train(model_type="logistic", scoring="recall", params=parametros_logistic, verbose=1)
model_resampled.train(model_type="decision_tree", scoring="recall", params=parametros_dt, verbose=1)
model_resampled.train(model_type="gradient_boosting", scoring="recall", params=parametros_gb, verbose=1)
model_resampled.train(model_type="xgboost", scoring="recall", params=parametros_xgb, verbose=1)
model_resampled.train(model_type="random_forest", scoring="recall", params=parametros_rf, verbose=1)
model_resampled.train(model_type="svc", scoring="recall", params=parametros_svc, verbose=1)
# Out:
# Fitting 5 folds for each of 43 candidates, totalling 215 fits
# Fitting 5 folds for each of 1440 candidates, totalling 7200 fits
# Fitting 5 folds for each of 162 candidates, totalling 810 fits
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# Fitting 5 folds for each of 960 candidates, totalling 4800 fits
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# SVC(C=0.1, degree=2, gamma='auto', kernel='poly', random_state=42)

# %%
model_resampled.plot_roc_curves()
# Out:
# El modelo 'svc' no soporta la función predict_proba y no se puede graficar la curva ROC.
# El modelo 'svc' no soporta la función predict_proba y no se puede graficar la curva ROC.

# %%
model_resampled.plot_confusion_matrix()

# %%
df_metrics_resampled = pd.DataFrame()
for k in model_resampled.resultados.keys():
    df_it = model_resampled.resultados[k]["metrics"]
    df_it["method"] = k
    df_metrics_resampled = pd.concat([df_metrics_resampled, df_it])

df_resultados_colores_resampled = df_metrics_resampled.copy()
df_resultados_colores_resampled.reset_index(inplace = True)
df_resultados_colores_resampled = df_resultados_colores_resampled.style.apply(color_filas_por_modelo, axis=1)
df_resultados_colores_resampled
# Out:
# <style type="text/css">
# #T_df90d_row0_col0, #T_df90d_row0_col1, #T_df90d_row0_col2, #T_df90d_row0_col3, #T_df90d_row0_col4, #T_df90d_row0_col5, #T_df90d_row0_col6, #T_df90d_row0_col7, #T_df90d_row0_col8, #T_df90d_row0_col9, #T_df90d_row1_col0, #T_df90d_row1_col1, #T_df90d_row1_col2, #T_df90d_row1_col3, #T_df90d_row1_col4, #T_df90d_row1_col5, #T_df90d_row1_col6, #T_df90d_row1_col7, #T_df90d_row1_col8, #T_df90d_row1_col9 {
#   background-color: #b3d1ff;
#   color: black;
# }
# #T_df90d_row2_col0, #T_df90d_row2_col1, #T_df90d_row2_col2, #T_df90d_row2_col3, #T_df90d_row2_col4, #T_df90d_row2_col5, #T_df90d_row2_col6, #T_df90d_row2_col7, #T_df90d_row2_col8, #T_df90d_row2_col9, #T_df90d_row3_col0, #T_df90d_row3_col1, #T_df90d_row3_col2, #T_df90d_row3_col3, #T_df90d_row3_col4, #T_df90d_row3_col5, #T_df90d_row3_col6, #T_df90d_row3_col7, #T_df90d_row3_col8, #T_df90d_row3_col9 {
#   background-color: #e6b3e0;
#   color: black;
# }
# #T_df90d_row4_col0, #T_df90d_row4_col1, #T_df90d_row4_col2, #T_df90d_row4_col3, #T_df90d_row4_col4, #T_df90d_row4_col5, #T_df90d_row4_col6, #T_df90d_row4_col7, #T_df90d_row4_col8, #T_df90d_row4_col9, #T_df90d_row5_col0, #T_df90d_row5_col1, #T_df90d_row5_col2, #T_df90d_row5_col3, #T_df90d_row5_col4, #T_df90d_row5_col5, #T_df90d_row5_col6, #T_df90d_row5_col7, #T_df90d_row5_col8, #T_df90d_row5_col9 {
#   background-color: #ffd9b3;
#   color: black;
# }
# #T_df90d_row6_col0, #T_df90d_row6_col1, #T_df90d_row6_col2, #T_df90d_row6_col3, #T_df90d_row6_col4, #T_df90d_row6_col5, #T_df90d_row6_col6, #T_df90d_row6_col7, #T_df90d_row6_col8, #T_df90d_row6_col9, #T_df90d_row7_col0, #T_df90d_row7_col1, #T_df90d_row7_col2, #T_df90d_row7_col3, #T_df90d_row7_col4, #T_df90d_row7_col5, #T_df90d_row7_col6, #T_df90d_row7_col7, #T_df90d_row7_col8, #T_df90d_row7_col9 {
#   background-color: #f7b3c2;
#   color: black;
# }
# #T_df90d_row8_col0, #T_df90d_row8_col1, #T_df90d_row8_col2, #T_df90d_row8_col3, #T_df90d_row8_col4, #T_df90d_row8_col5, #T_df90d_row8_col6, #T_df90d_row8_col7, #T_df90d_row8_col8, #T_df90d_row8_col9, #T_df90d_row9_col0, #T_df90d_row9_col1, #T_df90d_row9_col2, #T_df90d_row9_col3, #T_df90d_row9_col4, #T_df90d_row9_col5, #T_df90d_row9_col6, #T_df90d_row9_col7, #T_df90d_row9_col8, #T_df90d_row9_col9 {
#   background-color: #c2f0c2;
#   color: black;
# }
# #T_df90d_row10_col0, #T_df90d_row10_col1, #T_df90d_row10_col2, #T_df90d_row10_col3, #T_df90d_row10_col4, #T_df90d_row10_col5, #T_df90d_row10_col6, #T_df90d_row10_col7, #T_df90d_row10_col8, #T_df90d_row10_col9, #T_df90d_row11_col0, #T_df90d_row11_col1, #T_df90d_row11_col2, #T_df90d_row11_col3, #T_df90d_row11_col4, #T_df90d_row11_col5, #T_df90d_row11_col6, #T_df90d_row11_col7, #T_df90d_row11_col8, #T_df90d_row11_col9 {
#   background-color: #dbdcff;
#   color: black;
# }
# </style>
# <table id="T_df90d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_df90d_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_df90d_level0_col1" class="col_heading level0 col1" >precision</th>
#       <th id="T_df90d_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_df90d_level0_col3" class="col_heading level0 col3" >recall</th>
#       <th id="T_df90d_level0_col4" class="col_heading level0 col4" >f1_score</th>
#       <th id="T_df90d_level0_col5" class="col_heading level0 col5" >kappa</th>
#       <th id="T_df90d_level0_col6" class="col_heading level0 col6" >auc</th>
#       <th id="T_df90d_level0_col7" class="col_heading level0 col7" >time</th>
#       <th id="T_df90d_level0_col8" class="col_heading level0 col8" >n_jobs</th>
#       <th id="T_df90d_level0_col9" class="col_heading level0 col9" >method</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_df90d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_df90d_row0_col0" class="data row0 col0" >train</td>
#       <td id="T_df90d_row0_col1" class="data row0 col1" >0.678348</td>
#       <td id="T_df90d_row0_col2" class="data row0 col2" >0.644641</td>
#       <td id="T_df90d_row0_col3" class="data row0 col3" >0.559917</td>
#       <td id="T_df90d_row0_col4" class="data row0 col4" >0.613469</td>
#       <td id="T_df90d_row0_col5" class="data row0 col5" >0.290154</td>
#       <td id="T_df90d_row0_col6" class="data row0 col6" >0.649950</td>
#       <td id="T_df90d_row0_col7" class="data row0 col7" >0.004008</td>
#       <td id="T_df90d_row0_col8" class="data row0 col8" >None</td>
#       <td id="T_df90d_row0_col9" class="data row0 col9" >logistic</td>
#     </tr>
#     <tr>
#       <th id="T_df90d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_df90d_row1_col0" class="data row1 col0" >test</td>
#       <td id="T_df90d_row1_col1" class="data row1 col1" >0.610644</td>
#       <td id="T_df90d_row1_col2" class="data row1 col2" >0.604369</td>
#       <td id="T_df90d_row1_col3" class="data row1 col3" >0.538272</td>
#       <td id="T_df90d_row1_col4" class="data row1 col4" >0.572178</td>
#       <td id="T_df90d_row1_col5" class="data row1 col5" >0.206939</td>
#       <td id="T_df90d_row1_col6" class="data row1 col6" >0.596659</td>
#       <td id="T_df90d_row1_col7" class="data row1 col7" >0.004008</td>
#       <td id="T_df90d_row1_col8" class="data row1 col8" >None</td>
#       <td id="T_df90d_row1_col9" class="data row1 col9" >logistic</td>
#     </tr>
#     <tr>
#       <th id="T_df90d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_df90d_row2_col0" class="data row2 col0" >train</td>
#       <td id="T_df90d_row2_col1" class="data row2 col1" >0.925026</td>
#       <td id="T_df90d_row2_col2" class="data row2 col2" >0.915193</td>
#       <td id="T_df90d_row2_col3" class="data row2 col3" >0.904959</td>
#       <td id="T_df90d_row2_col4" class="data row2 col4" >0.914883</td>
#       <td id="T_df90d_row2_col5" class="data row2 col5" >0.830403</td>
#       <td id="T_df90d_row2_col6" class="data row2 col6" >0.973053</td>
#       <td id="T_df90d_row2_col7" class="data row2 col7" >0.003000</td>
#       <td id="T_df90d_row2_col8" class="data row2 col8" >12</td>
#       <td id="T_df90d_row2_col9" class="data row2 col9" >decision_tree</td>
#     </tr>
#     <tr>
#       <th id="T_df90d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_df90d_row3_col0" class="data row3 col0" >test</td>
#       <td id="T_df90d_row3_col1" class="data row3 col1" >0.822500</td>
#       <td id="T_df90d_row3_col2" class="data row3 col2" >0.821602</td>
#       <td id="T_df90d_row3_col3" class="data row3 col3" >0.812346</td>
#       <td id="T_df90d_row3_col4" class="data row3 col4" >0.817391</td>
#       <td id="T_df90d_row3_col5" class="data row3 col5" >0.643027</td>
#       <td id="T_df90d_row3_col6" class="data row3 col6" >0.889089</td>
#       <td id="T_df90d_row3_col7" class="data row3 col7" >0.003000</td>
#       <td id="T_df90d_row3_col8" class="data row3 col8" >12</td>
#       <td id="T_df90d_row3_col9" class="data row3 col9" >decision_tree</td>
#     </tr>
#     <tr>
#       <th id="T_df90d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_df90d_row4_col0" class="data row4 col0" >train</td>
#       <td id="T_df90d_row4_col1" class="data row4 col1" >0.994698</td>
#       <td id="T_df90d_row4_col2" class="data row4 col2" >0.981790</td>
#       <td id="T_df90d_row4_col3" class="data row4 col3" >0.969008</td>
#       <td id="T_df90d_row4_col4" class="data row4 col4" >0.981685</td>
#       <td id="T_df90d_row4_col5" class="data row4 col5" >0.963585</td>
#       <td id="T_df90d_row4_col6" class="data row4 col6" >0.998649</td>
#       <td id="T_df90d_row4_col7" class="data row4 col7" >0.019011</td>
#       <td id="T_df90d_row4_col8" class="data row4 col8" >12</td>
#       <td id="T_df90d_row4_col9" class="data row4 col9" >gradient_boosting</td>
#     </tr>
#     <tr>
#       <th id="T_df90d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_df90d_row5_col0" class="data row5 col0" >test</td>
#       <td id="T_df90d_row5_col1" class="data row5 col1" >0.933842</td>
#       <td id="T_df90d_row5_col2" class="data row5 col2" >0.922330</td>
#       <td id="T_df90d_row5_col3" class="data row5 col3"
